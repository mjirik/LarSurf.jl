# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = [10, 8]

# %%
# df = pd.read_csv("../exp_full_reduced.csv")
df = pd.read_csv("../exp_surface_extraction2.csv")
df.keys()
# Out:
# Index(['data_size_1', 'elapsed', 'boundary3_size_1', 'boundary3_size_2',
#        'data_size_3', 'data_voxel_number', 'data_non_zeros_number',
#        'boundary3_size_3', 'data_zeros_number', 'datetime', 'alocated',
#        'experiment', 'fcn', 'data_size_2'],
#       dtype='object')

# %%
df
# Out:
#      data_size_1      elapsed  boundary3_size_1  boundary3_size_2  \
# 0             10     0.000111                 8                 8
# 1             10     0.000136                 8                 8
# 2             10     0.243849                 8                 8
# 3             10     0.000585                 8                 8
# 4             10     0.001248                 8                 8
# 5             10     0.000753                 8                 8
# 6             10     0.001086                 8                 8
# 7             10     0.002206                 8                 8
# 8             20     0.790565                16                16
# 9             20     0.002064                16                16
# 10            20     0.002366                16                16
# 11            20     0.006124                16                16
# 12            20     0.004240                16                16
# 13            40     2.956379                32                32
# 14            40     0.009414                32                32
# 15            40     0.034359                32                32
# 16            40     0.060929                32                32
# 17            40     0.011281                32                32
# 18            70    22.822458                64                64
# 19            70     0.096480                64                64
# 20            70     0.126281                64                64
# 21            70     0.623454                64                64
# 22            70     0.114128                64                64
# 23            40     5.216290                16                16
# 24            40     0.006126                16                16
# 25            40     6.274580                16                16
# 26            40     0.019618                16                16
# 27            40     0.019558                16                16
# 28            40     0.425203                16                16
# 29            40     0.066897                16                16
# ..           ...          ...               ...               ...
# 188          100     0.334724                16                16
# 189          100     0.266539                16                16
# 190          100     0.322466                16                16
# 191          100     0.741452                16                16
# 192          100     0.264475                16                16
# 193          100     0.305777                32                32
# 194          100     1.511524                32                32
# 195          100     0.254987                32                32
# 196          100     0.693291                32                32
# 197          100     0.267204                32                32
# 198          100     0.486620                64                64
# 199          100     0.241556                64                64
# 200          100     0.287872                64                64
# 201          100     0.731068                64                64
# 202          100     0.255628                64                64
# 203          512   978.955540                 8                 8
# 204          512   976.155490                 8                 8
# 205          512  7143.368965                 8                 8
# 206          512  1071.118854                 8                 8
# 207          512  1165.161209                 8                 8
# 208          512   214.148505                16                16
# 209          512   202.203758                16                16
# 210          512   968.932129                16                16
# 211          512   387.129929                16                16
# 212          512   305.779452                16                16
# 213          512   115.112921                32                32
# 214          512   100.579992                32                32
# 215          512   197.450183                32                32
# 216          512   131.883406                32                32
# 217          512    72.627712                32                32
#
#      data_size_3  data_voxel_number  data_non_zeros_number  boundary3_size_3  \
# 0             10               1000                    125                 8
# 1             10               1000                    125                 8
# 2             10               1000                    125                 8
# 3             10               1000                    125                 8
# 4             10               1000                    125                 8
# 5             10               1000                    125                 8
# 6             10               1000                    125                 8
# 7             10               1000                    125                 8
# 8             20               8000                    729                16
# 9             20               8000                    729                16
# 10            20               8000                    729                16
# 11            20               8000                    729                16
# 12            20               8000                    729                16
# 13            40              64000                   4913                32
# 14            40              64000                   4913                32
# 15            40              64000                   4913                32
# 16            40              64000                   4913                32
# 29               59087  2019-05-21 00:19:34       23060704           small b3
# ..                 ...                  ...            ...                ...
# 188             931079  2019-05-21 04:41:46      126685856      boundary size
# 189             931079  2019-05-21 04:41:46      105730320      boundary size
# 190             931079  2019-05-21 04:41:47      187921440      boundary size
# 191             931079  2019-05-21 04:41:47      304131600      boundary size
# 192             931079  2019-05-21 04:41:48      105733968      boundary size
# 193             931079  2019-05-21 04:41:48      113229120      boundary size
# 194             931079  2019-05-21 04:41:49       92273936      boundary size
# 195             931079  2019-05-21 04:41:50       93809408      boundary size
# 196             931079  2019-05-21 04:41:50      289621664      boundary size
# 197             931079  2019-05-21 04:41:51       92277232      boundary size
# 198             931079  2019-05-21 04:41:51      107070496      boundary size
# 199             931079  2019-05-21 04:41:52       86114960      boundary size
# 200             931079  2019-05-21 04:41:52       75709632      boundary size
# 201             931079  2019-05-21 04:41:53      280772112      boundary size
# 202             931079  2019-05-21 04:41:53       86118784      boundary size
# 203          125518348  2019-05-21 04:58:12   569293036384  boundary size big
# 204          125518348  2019-05-21 05:14:36   566197409680  boundary size big
# 205          125518348  2019-05-21 07:13:40  9331240586256  boundary size big
# 206          125518348  2019-05-21 07:31:31   590811093984  boundary size big
# 207          125518348  2019-05-21 07:51:04   566200024416  boundary size big
# 208          125518348  2019-05-21 07:54:39    22258357664  boundary size big
# 209          125518348  2019-05-21 07:58:09    19162731136  boundary size big
# 210          125518348  2019-05-21 08:14:19  1051583474480  boundary size big
# 211          125518348  2019-05-21 08:20:47    45849494784  boundary size big
# 212          125518348  2019-05-21 08:25:54    19162219872  boundary size big
# 213          125518348  2019-05-21 08:27:50    11818688298  boundary size big
# 214          125518348  2019-05-21 08:29:41     8723061770  boundary size big
# 215          125518348  2019-05-21 08:32:58   133996414416  boundary size big
# 216          125518348  2019-05-21 08:35:11    35129315274  boundary size big
# 217          125518348  2019-05-21 08:36:24     8723699242  boundary size big
#
#                                                    fcn  data_size_2
# 0                             LarSurf.get_surface_grid           10
# 1                         LarSurf.get_surface_grid_old           10
# 2              LarSurf.get_surface_grid_per_block_full           10
# 3         LarSurf.get_surface_grid_per_block_FVreduced           10
# 4    LarSurf.get_surface_grid_per_block_Vreduced_FV...           10
# 5    LarSurf.get_surface_grid_per_block_Vreduced_FV...           10
# 6    LarSurf.get_surface_grid_per_block_Vreduced_FV...           10
# 7    LarSurf.get_surface_grid_per_block_Vreduced_FV...           10
# 8         LarSurf.get_surface_grid_per_block_FVreduced           20
# 9    LarSurf.get_surface_grid_per_block_Vreduced_FV...           20
# 10   LarSurf.get_surface_grid_per_block_Vreduced_FV...           20
# 11   LarSurf.get_surface_grid_per_block_Vreduced_FV...           20
# 12   LarSurf.get_surface_grid_per_block_Vreduced_FV...           20
# 13        LarSurf.get_surface_grid_per_block_FVreduced           40
# 14   LarSurf.get_surface_grid_per_block_Vreduced_FV...           40
# 15   LarSurf.get_surface_grid_per_block_Vreduced_FV...           40
# 16   LarSurf.get_surface_grid_per_block_Vreduced_FV...           40
# 17   LarSurf.get_surface_grid_per_block_Vreduced_FV...           40
# 18        LarSurf.get_surface_grid_per_block_FVreduced           70
# 19   LarSurf.get_surface_grid_per_block_Vreduced_FV...           70
# 20   LarSurf.get_surface_grid_per_block_Vreduced_FV...           70
# 21   LarSurf.get_surface_grid_per_block_Vreduced_FV...           70
# 22   LarSurf.get_surface_grid_per_block_Vreduced_FV...           70
# 23                            LarSurf.get_surface_grid           40
# 24                        LarSurf.get_surface_grid_old           40
# 25             LarSurf.get_surface_grid_per_block_full           40
# 26        LarSurf.get_surface_grid_per_block_FVreduced           40
# 27   LarSurf.get_surface_grid_per_block_Vreduced_FV...           40
# 28   LarSurf.get_surface_grid_per_block_Vreduced_FV...           40
# 29   LarSurf.get_surface_grid_per_block_Vreduced_FV...           40
# ..                                                 ...          ...
# 188       LarSurf.get_surface_grid_per_block_FVreduced          100
# 189  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 190  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 191  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 192  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 193       LarSurf.get_surface_grid_per_block_FVreduced          100
# 194  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 195  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 196  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 197  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 198       LarSurf.get_surface_grid_per_block_FVreduced          100
# 199  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 200  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 201  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 202  LarSurf.get_surface_grid_per_block_Vreduced_FV...          100
# 203       LarSurf.get_surface_grid_per_block_FVreduced          512
# 204  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 205  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 206  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 207  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 208       LarSurf.get_surface_grid_per_block_FVreduced          512
# 209  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 210  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 211  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 212  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 213       LarSurf.get_surface_grid_per_block_FVreduced          512
# 214  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 215  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 216  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
# 217  LarSurf.get_surface_grid_per_block_Vreduced_FV...          512
#
# [218 rows x 14 columns]

# %%
# def fab(row):
#     retval = "memory files" if row["allow_files"] & row["allow_memory"] else "files" if row["allow_files"] & ~row["allow_memory"] else "memory" if ~row["allow_files"] & row["allow_memory"] else "computation"

#     return retval

# df["allow"] = df.apply(fab, axis=1)

# %%
# df
# df.experiment.str.contains("seg")
# df.experiment.str.contains("seg") and 
# df.data_size_1<100 & df.experiment.str.contains("seg")

# %% [markdown]
# # Small data 40x41x42, b3 16x16x16

# %%
ax = plt.subplot(111)
sns.barplot(data=df[df.experiment.str.contains("small b3")], x="data_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(yscale="log")
# plt.legend(loc='upper left')
# Out:
# [None]

# %%
# ax = plt.subplot(111)
# sns.barplot(data=df[df.experiment.str.contains("small b3") & df.fcn.str.contains("V")], x="data_size_1", y="elapsed", hue="fcn")
# # plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# # plt.legend(loc='upper left')

# %% [markdown]
# # Data size

# %%
ax = plt.subplot(111)
sns.barplot(data=df[df.experiment.str.contains("data size")], x="data_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.set(xscale="log", yscale="log")
ax.set(yscale="log")
# Out:
# [None]

# %%
# ax = plt.subplot(111)
lm = sns.lmplot(data=df[df.experiment.str.contains("data size")], x="data_voxel_number", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
# plt.ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# # Boundary size

# %%
# ax = plt.subplot(111)
lm = sns.lmplot(data=df[df.experiment.str.contains("boundary size")], x="boundary3_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
# plt.ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = plt.subplot(111)
lm = sns.barplot(data=df[df.experiment.str.contains("boundary size")], x="boundary3_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.set(yscale="log")

# %%
ax = plt.subplot(111)
lm = sns.barplot(data=df[df.experiment.str.contains("boundary size")], x="boundary3_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(yscale="log")
# Out:
# [None]

# %%
# ax = plt.subplot(111)
plt.figure(figsize=(20,8))
lm = sns.factorplot(data=df[df.experiment.str.contains("boundary size")], x="boundary3_size_1", y="elapsed", hue="fcn", kind='violin')
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.set(yscale="log")
# Out:
# C:\Users\Jirik\Miniconda3\envs\julia\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
