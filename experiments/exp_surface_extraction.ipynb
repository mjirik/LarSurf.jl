# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = [10, 8]

# %%
# df = pd.read_csv("../exp_full_reduced.csv")
df = pd.read_csv("../exp_surface_extraction5_tesla_tmp3.csv")
df.keys()
# Out:
# Index(['data_size_1', 'elapsed', 'boundary3_size_1', 'boundary3_size_2',
#        'nprocs', 'data_size_3', 'data_voxel_number', 'data_non_zeros_number',
#        'boundary3_size_3', 'data_zeros_number', 'datetime', 'alocated',
#        'experiment', 'fcn', 'data_size_2', 'nworkers', 'hostname', 'ncores',
#        'jlfile'],
#       dtype='object')

# %%
df
# Out:
#      data_size_1       elapsed  boundary3_size_1  boundary3_size_2  nprocs  \
# 0             10      0.672525                 8                 8       4
# 1             10      0.303173                 8                 8       4
# 2             10      0.223271                 8                 8       4
# 3             10      0.001063                 8                 8       4
# 4             10      0.000823                 8                 8       4
# 5             10      0.071555                 8                 8       4
# 6             10      0.000294                 8                 8       4
# 7             10      0.000213                 8                 8       4
# 8             20      0.900081                16                16       4
# 9             20      0.579138                16                16       4
# 10            20      0.937511                16                16       4
# ...

# %%
# def fab(row):
#     retval = "memory files" if row["allow_files"] & row["allow_memory"] else "files" if row["allow_files"] & ~row["allow_memory"] else "memory" if ~row["allow_files"] & row["allow_memory"] else "computation"

#     return retval

# df["allow"] = df.apply(fab, axis=1)

# %%
# df
# df.experiment.str.contains("seg")
# df.experiment.str.contains("seg") and 
# df.data_size_1<100 & df.experiment.str.contains("seg")

# %% [markdown]
# # Small data 40x41x42, b3 16x16x16

# %%
ax = plt.subplot(111)
sns.barplot(data=df[df.experiment.str.contains("small b3")], x="data_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(yscale="log")
# plt.legend(loc='upper left')
# Out:
# [None]

# %%
# ax = plt.subplot(111)
# sns.barplot(data=df[df.experiment.str.contains("small b3") & df.fcn.str.contains("V")], x="data_size_1", y="elapsed", hue="fcn")
# # plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# # plt.legend(loc='upper left')

# %% [markdown]
# # Data size

# %%
ax = plt.subplot(111)
sns.barplot(data=df[df.experiment.str.contains("data size")], x="data_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.set(xscale="log", yscale="log")
ax.set(yscale="log")
# Out:
# [None]

# %%
# ax = plt.subplot(111)
lm = sns.lmplot(data=df[df.experiment.str.contains("data size")], x="data_voxel_number", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
# plt.ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# # Boundary size

# %%
# ax = plt.subplot(111)
lm = sns.lmplot(data=df[df.experiment.str.contains("boundary size")], x="boundary3_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
# plt.ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = plt.subplot(111)
lm = sns.barplot(data=df[df.experiment.str.contains("boundary size")], x="boundary3_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.set(yscale="log")

# %%
ax = plt.subplot(111)
lm = sns.barplot(data=df[df.experiment.str.contains("boundary size")], x="boundary3_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(yscale="log")
# Out:
# [None]

# %% [markdown]
# # Boundary size on big data

# %%
ax = plt.subplot(111)
dfsel = df[df.experiment == "boundary size big"]
lm = sns.barplot(data=dfsel, x="boundary3_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(yscale="log")
# print(dfsel["n"])
# Out:
# [None]

# %%
ax = plt.subplot(111)
dfsel = df[df.experiment.str.contains("boundary size big 32")]
lm = sns.barplot(data=dfsel, x="boundary3_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(yscale="log")
# print(dfsel["n"])
# Out:
# [None]

# %%
# ax = plt.subplot(111)
# plt.figure(figsize=(20,8))
# lm = sns.factorplot(data=df[df.experiment.str.contains("boundary size")], x="boundary3_size_1", y="elapsed", hue="fcn", kind='violin')
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.set(yscale="log")
