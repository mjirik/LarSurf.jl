# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import seaborn as sns

# %%
# df = pd.read_csv("../exp_full_reduced.csv")
df = pd.read_csv("../exp_surface_extraction.csv")
df.keys()
# Out:
# Index(['data_size_1', 'elapsed', 'boundary3_size_1', 'boundary3_size_2',
#        'data_size_3', 'data_voxel_number', 'data_non_zeros_number',
#        'boundary3_size_3', 'data_zeros_number', 'datetime', 'alocated',
#        'experiment', 'fcn', 'data_size_2'],
#       dtype='object')

# %%
df
# Out:
#     data_size_1   elapsed  boundary3_size_1  boundary3_size_2  data_size_3  \
# 0            20  0.000736                16                16           22
# 1            20  0.000789                16                16           22
# 2            20  0.472804                16                16           22
# 3            20  0.002107                16                16           22
# 4            20  0.001823                16                16           22
# 5            20  0.006973                16                16           22
# 6            20  0.011466                16                16           22
# 7            20  0.042176                16                16           22
# 8            40  0.018976                32                32           42
# 9            40  0.016719                32                32           42
# 10           40  0.038157                32                32           42
# 11           40  0.072163                32                32           42
# 12           40  0.012395                32                32           42
# 13           70  0.135856                64                64           72
# 14           70  0.103687                64                64           72
# 15           70  0.131354                64                64           72
# 16           70  0.218863                64                64           72
# 17           70  0.088666                64                64           72
# 18           40  5.640482                16                16           42
# 19           40  0.006339                16                16           42
# 20           40  6.774448                16                16           42
# 21           40  0.056424                16                16           42
# 22           40  0.018796                16                16           42
# 23           40  0.070852                16                16           42
# 24           40  0.087449                16                16           42
# 25           40  0.014323                16                16           42
# 26           40  0.004974                16                16           42
# 27           40  0.006644                16                16           42
# 28           40  5.603046                16                16           42
# 29           40  0.044166                16                16           42
# ..          ...       ...               ...               ...          ...
# 63          100  0.919625                 8                 8          102
# 64          100  0.978815                 8                 8          102
# 65          100  0.780872                 8                 8          102
# 66          100  0.912807                 8                 8          102
# 67          100  0.410495                 8                 8          102
# 68          100  0.344892                16                16          102
# 69          100  0.247550                16                16          102
# 70          100  0.298667                16                16          102
# 71          100  0.733424                16                16          102
# 72          100  0.254192                16                16          102
# 73          100  1.014873                 8                 8          102
# 74          100  0.399279                 8                 8          102
# 75          100  0.768190                 8                 8          102
# 76          100  0.822855                 8                 8          102
# 77          100  0.389712                 8                 8          102
# 78          100  0.311450                16                16          102
# 79          100  0.831450                16                16          102
# 80          100  0.301054                16                16          102
# 81          100  0.700388                16                16          102
# 82          100  0.275609                16                16          102
# 83          100  0.396368                32                32          102
# 84          100  1.317978                32                32          102
# 85          100  0.246291                32                32          102
# 86          100  0.670358                32                32          102
# 87          100  0.279224                32                32          102
# 88          100  0.312734                64                64          102
# 89          100  0.256253                64                64          102
# 90          100  0.256303                64                64          102
# 91          100  0.725423                64                64          102
# 92          100  1.419005                64                64          102
#
#     data_voxel_number  data_non_zeros_number  boundary3_size_3  \
# 0                9240                    729                16
# 1                9240                    729                16
# 2                9240                    729                16
# 3                9240                    729                16
# 4                9240                    729                16
# 5                9240                    729                16
# 6                9240                    729                16
# 7                9240                    729                16
# 8               68880                   4913                32
# 9               68880                   4913                32
# 10              68880                   4913                32
# 11              68880                   4913                32
# 12              68880                   4913                32
# 13             357840                  24389                64
# 14             357840                  24389                64
# 15             357840                  24389                64
# 16             357840                  24389                64
# 17             357840                  24389                64
# 67             961279  2019-05-20 23:33:48   193073232      data size
# 68             961279  2019-05-20 23:33:48   128486432      data size
# 69             961279  2019-05-20 23:33:49   106746304      data size
# 70             961279  2019-05-20 23:33:49   187982976      data size
# 71             961279  2019-05-20 23:33:50   311209472      data size
# 72             961279  2019-05-20 23:33:50   106749952      data size
# 73             961279  2019-05-20 23:47:12   214809872  boundary size
# 74             961279  2019-05-20 23:47:12   193069568  boundary size
# 75             961279  2019-05-20 23:47:13   795228816  boundary size
# 76             961279  2019-05-20 23:47:14   379524704  boundary size
# 77             961279  2019-05-20 23:47:14   193073232  boundary size
# 78             961279  2019-05-20 23:47:15   128486432  boundary size
# 79             961279  2019-05-20 23:47:16   106746480  boundary size
# 80             961279  2019-05-20 23:47:16   187982976  boundary size
# 81             961279  2019-05-20 23:47:17   311209472  boundary size
# 82             961279  2019-05-20 23:47:17   106749952  boundary size
# 83             961279  2019-05-21 00:05:14   115014000  boundary size
# 84             961279  2019-05-21 00:05:16    93274048  boundary size
# 85             961279  2019-05-21 00:05:16    93869888  boundary size
# 86             961279  2019-05-21 00:05:17   296568256  boundary size
# 87             961279  2019-05-21 00:05:17    93277520  boundary size
# 88             961279  2019-05-21 00:05:17   108856224  boundary size
# 89             961279  2019-05-21 00:05:18    87116096  boundary size
# 90             961279  2019-05-21 00:05:18    75769920  boundary size
# 91             961279  2019-05-21 00:05:19   287648704  boundary size
# 92             961279  2019-05-21 00:05:20    87120096  boundary size
#
#                                                   fcn  data_size_2
# 0                            lario3d.get_surface_grid           21
# 1                        lario3d.get_surface_grid_old           21
# 2             lario3d.get_surface_grid_per_block_full           21
# 3        lario3d.get_surface_grid_per_block_FVreduced           21
# 4   lario3d.get_surface_grid_per_block_Vreduced_FV...           21
# 5   lario3d.get_surface_grid_per_block_Vreduced_FV...           21
# 6   lario3d.get_surface_grid_per_block_Vreduced_FV...           21
# 7   lario3d.get_surface_grid_per_block_Vreduced_FV...           21
# 8        lario3d.get_surface_grid_per_block_FVreduced           41
# 9   lario3d.get_surface_grid_per_block_Vreduced_FV...           41
# 10  lario3d.get_surface_grid_per_block_Vreduced_FV...           41
# 11  lario3d.get_surface_grid_per_block_Vreduced_FV...           41
# 12  lario3d.get_surface_grid_per_block_Vreduced_FV...           41
# 13       lario3d.get_surface_grid_per_block_FVreduced           71
# 14  lario3d.get_surface_grid_per_block_Vreduced_FV...           71
# 15  lario3d.get_surface_grid_per_block_Vreduced_FV...           71
# 16  lario3d.get_surface_grid_per_block_Vreduced_FV...           71
# 17  lario3d.get_surface_grid_per_block_Vreduced_FV...           71
# 18                           lario3d.get_surface_grid           41
# 19                       lario3d.get_surface_grid_old           41
# 20            lario3d.get_surface_grid_per_block_full           41
# 21       lario3d.get_surface_grid_per_block_FVreduced           41
# 22  lario3d.get_surface_grid_per_block_Vreduced_FV...           41
# 23  lario3d.get_surface_grid_per_block_Vreduced_FV...           41
# 24  lario3d.get_surface_grid_per_block_Vreduced_FV...           41
# 25  lario3d.get_surface_grid_per_block_Vreduced_FV...           41
# 26                           lario3d.get_surface_grid           41
# 27                       lario3d.get_surface_grid_old           41
# 28            lario3d.get_surface_grid_per_block_full           41
# 29       lario3d.get_surface_grid_per_block_FVreduced           41
# ..                                                ...          ...
# 63       lario3d.get_surface_grid_per_block_FVreduced          101
# 64  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 65  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 66  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 67  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 68       lario3d.get_surface_grid_per_block_FVreduced          101
# 69  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 70  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 71  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 72  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 73       lario3d.get_surface_grid_per_block_FVreduced          101
# 74  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 75  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 76  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 77  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 78       lario3d.get_surface_grid_per_block_FVreduced          101
# 79  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 80  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 81  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 82  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 83       lario3d.get_surface_grid_per_block_FVreduced          101
# 84  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 85  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 86  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 87  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 88       lario3d.get_surface_grid_per_block_FVreduced          101
# 89  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 90  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 91  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
# 92  lario3d.get_surface_grid_per_block_Vreduced_FV...          101
#
# [93 rows x 14 columns]

# %%
# def fab(row):
#     retval = "memory files" if row["allow_files"] & row["allow_memory"] else "files" if row["allow_files"] & ~row["allow_memory"] else "memory" if ~row["allow_files"] & row["allow_memory"] else "computation"

#     return retval

# df["allow"] = df.apply(fab, axis=1)

# %%
# df
# df.experiment.str.contains("seg")
# df.experiment.str.contains("seg") and 
# df.data_size_1<100 & df.experiment.str.contains("seg")

# %% [markdown]
# # Small data 40x41x42, b3 16x16x16

# %%
ax = plt.subplot(111)
sns.barplot(data=df[df.experiment.str.contains("small b3")], x="data_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(yscale="log")
# plt.legend(loc='upper left')
# Out:
# C:\Users\Jirik\Miniconda3\envs\julia\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None]

# %%
# ax = plt.subplot(111)
# sns.barplot(data=df[df.experiment.str.contains("small b3") & df.fcn.str.contains("V")], x="data_size_1", y="elapsed", hue="fcn")
# # plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# # plt.legend(loc='upper left')

# %% [markdown]
# # Data size

# %%
ax = plt.subplot(111)
sns.barplot(data=df[df.experiment.str.contains("data size")], x="data_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.set(xscale="log", yscale="log")
ax.set(yscale="log")
# Out:
# [None]

# %%
# ax = plt.subplot(111)
lm = sns.lmplot(data=df[df.experiment.str.contains("data size")], x="data_voxel_number", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
# plt.ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# # Boundary size

# %%
# ax = plt.subplot(111)
lm = sns.lmplot(data=df[df.experiment.str.contains("boundary size")], x="boundary3_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
# plt.ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = plt.subplot(111)
lm = sns.barplot(data=df[df.experiment.str.contains("boundary size")], x="boundary3_size_1", y="elapsed", hue="fcn")
# plt.legend(title='Smoker', loc='upper left', labels=['Hell Yeh', 'Nah Bruh'])

# lm.set(xscale="log", yscale="log")
# lm.set( yscale="log")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
