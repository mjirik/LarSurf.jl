# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("../exp_full_reduced.csv")
df.keys()
# Out:
# Index(['data_size_1', 'elapsed', 'boundary3_size_1', 'boundary3_size_2',
#        'data_size_3', 'data_non_zeros_number', 'boundary3_size_3',
#        'data_zeros_number', 'datetime', 'alocated', 'experiment',
#        'data_size_2'],
#       dtype='object')

# %%
df
# Out:
#     data_size_1     elapsed  boundary3_size_1  boundary3_size_2  data_size_3  \
# 0             5    0.002481                 2                 2            7
# 1             5    0.001099                 2                 2            7
# 2             5    0.000292                 2                 2            7
# 3             5    0.000207                 2                 2            7
# 4             5    0.005550                 2                 2            7
# 5             5    0.001200                 2                 2            7
# 6             5    0.002107                 2                 2            7
# 7             5    0.018199                 2                 2            7
# 8            25    0.170848                 2                 2           35
# 9            25    0.005123                 2                 2           35
# 10           25    0.002680                 2                 2           35
# 11           25    1.762426                 2                 2           35
# 12           25    0.187869                 2                 2           35
# 13           25    0.193458                 2                 2           35
# 14           25    2.041668                 2                 2           35
# 15           25    1.367626                16                16           35
# 16           25    0.006113                16                16           35
# 17           25    0.002757                16                16           35
# 18           25    1.731779                16                16           35
# 19           25    0.051915                16                16           35
# 20           25    0.067929                16                16           35
# 21           25    2.432195                16                16           35
# 22           50    1.648275                 2                 2           70
# 23           50    0.058036                 2                 2           70
# 24           50    0.045301                 2                 2           70
# 25           50   20.891573                 2                 2           70
# 26           50    2.157253                 2                 2           70
# 27           50    2.077822                 2                 2           70
# 28           50   22.878535                 2                 2           70
# 29           50    0.209808                16                16           70
# ..          ...         ...               ...               ...          ...
# 53          200   12.533978                32                32          280
# 54          200    2.361107                32                32          280
# 55          200    1.716763                32                32          280
# 56          200   14.481634                32                32          280
# 57          200   13.967274                32                32          280
# 58          200   24.579985                64                64          280
# 59          200    1.660287                64                64          280
# 60          200    1.895730                64                64          280
# 61          200   26.301375                64                64          280
# 62          200   25.503212                64                64          280
# 63          250   29.368094                32                32          350
# 64          250    3.871742                32                32          350
# 65          250    2.710586                32                32          350
# 66          250   34.713278                32                32          350
# 67          250   30.115714                32                32          350
# 68          300   69.588904                32                32          420
# 69          300    6.164307                32                32          420
# 70          300    5.202101                32                32          420
# 71          300   72.643056                32                32          420
# 72          300   72.259878                32                32          420
# 73          350  127.465221                32                32          490
# 74          350   10.477754                32                32          490
# 75          350    8.305691                32                32          490
# 76          350  133.478276                32                32          490
# 77          350  129.836672                32                32          490
# 78          400  308.371925                32                32          560
# 79          400   15.462338                32                32          560
# 80          400   11.552398                32                32          560
# 81          400  317.196180                32                32          560
# 82          400  314.878239                32                32          560
#
#     data_non_zeros_number  boundary3_size_3  data_zeros_number  \
# 0                     130                 2                130
# 1                     130                 2                130
# 2                     130                 2                130
# 3                     130                 2                130
# 4                     130                 2                130
# 5                     130                 2                130
# 6                     130                 2                130
# 7                     130                 2                130
# 8                   20874                 2              20874
# 9                   20874                 2              20874
# 10                  20874                 2              20874
# 11                  20874                 2              20874
# 12                  20874                 2              20874
# 13                  20874                 2              20874
# 14                  20874                 2              20874
# 15                  20874                16              20874
# 16                  20874                16              20874
# 17                  20874                16              20874
# 53  2019-05-08 00:14:10   4068936652           Fchar          240
# 54  2019-05-08 00:14:12    239633152      Vr and FVr          240
# 55  2019-05-08 00:14:14    525186064       V and FVr          240
# 56  2019-05-08 00:14:29   4308569884  seg Vr and FVr          240
# 57  2019-05-08 00:14:43   4594122764   seg V and FVr          240
# 58  2019-05-08 00:15:07   3770000680           Fchar          240
# 59  2019-05-08 00:15:09    239633152      Vr and FVr          240
# 60  2019-05-08 00:15:11    525186064       V and FVr          240
# 61  2019-05-08 00:15:37   4009633912  seg Vr and FVr          240
# 62  2019-05-08 00:16:03   4295186792   seg V and FVr          240
# 63  2019-05-08 00:16:32   7716084215           Fchar          300
# 64  2019-05-08 00:16:36    381061808      Vr and FVr          300
# 65  2019-05-08 00:16:39    945543760       V and FVr          300
# 66  2019-05-08 00:17:14   8097146263  seg Vr and FVr          300
# 67  2019-05-08 00:17:44   8661628183   seg V and FVr          300
# 68  2019-05-08 00:18:54  13666060443           Fchar          360
# 69  2019-05-08 00:19:00    562875376      Vr and FVr          360
# 70  2019-05-08 00:19:05   1540748880       V and FVr          360
# 71  2019-05-08 00:20:18  14228936059  seg Vr and FVr          360
# 72  2019-05-08 00:21:30  15206809531   seg V and FVr          360
# 73  2019-05-08 00:26:02  22959624728           Fchar          420
# 74  2019-05-08 00:26:12    898482880      Vr and FVr          420
# 75  2019-05-08 00:26:21   2344187152       V and FVr          420
# 76  2019-05-08 00:28:34  22248365552  seg Vr and FVr          420
# 77  2019-05-08 00:30:45  23694069792   seg V and FVr          420
# 78  2019-05-08 00:35:54  33307392280           Fchar          480
# 79  2019-05-08 00:36:10   1016211712      Vr and FVr          480
# 80  2019-05-08 00:36:22   3381904272       V and FVr          480
# 81  2019-05-08 00:41:42  33267026304  seg Vr and FVr          480
# 82  2019-05-08 00:46:58  35632718832   seg V and FVr          480
#
# [83 rows x 12 columns]

# %%
# def fab(row):
#     retval = "memory files" if row["allow_files"] & row["allow_memory"] else "files" if row["allow_files"] & ~row["allow_memory"] else "memory" if ~row["allow_files"] & row["allow_memory"] else "computation"

#     return retval

# df["allow"] = df.apply(fab, axis=1)

# %%
# df
# df.experiment.str.contains("seg")
# df.experiment.str.contains("seg") and 
# df.data_size_1<100 & df.experiment.str.contains("seg")

# %% [markdown]
# # Compare model extraction methods

# %%
sns.barplot(data=df[df.experiment.str.contains("seg")], x="data_size_1", y="elapsed", hue="experiment")

# %%
sns.barplot(data=df[df.experiment.str.contains("seg") & (df.data_size_1<100)], x="data_size_1", y="elapsed", hue="experiment")

# %% [markdown]
# # Compare size of boundary matrix

# %%
sns.barplot(data=df[df.experiment.str.contains("Fchar")], x="data_size_1", y="elapsed", hue="boundary3_size_1")

# %%
sns.barplot(data=df[df.experiment.str.contains("Fchar") & (df.data_size_1 < 250)], x="data_size_1", y="elapsed", hue="boundary3_size_1")

# %%
sns.barplot(data=df[~df.experiment.str.contains("seg") & ~df.experiment.str.contains("Fchar")], x="boundary3_size_1", y="elapsed", hue="experiment")

# %%
# sns.lmplot(data=df, x="block_", y="time", hue="acquisition", order=3)
